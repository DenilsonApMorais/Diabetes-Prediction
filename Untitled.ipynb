# %% [markdown]
# # Tópicos Especiais em Engenharia de Computação

# %% [markdown]
# ## Trabalho Final

# %% [markdown]
# ## Diabetes prediction dataset

# %% [markdown]
# ### Carlos Eduardo de Sousa
# ### Denilson Aparecido de Morais

# %% [markdown]
# ## 1. Preparação do ambiente

# %%
#funcao para deixar o jupyter com celulas preenchendo toda a tela
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#importacao de bibliotecas

import numpy as np

from sklearn.preprocessing import LabelEncoder

#bibliotecas para trabalhar com dados e graficos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

#bibliotecas do scikit-learn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.preprocessing import OrdinalEncoder

#biblioteca para exportacoes e importacoes de arquivos
from joblib import dump, load

#biblioteca para implementar uma barra de progresso
import progressbar

#biblioteca para tocar sons
import pygame

#bibliotecas para deep learning
import tensorflow.keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, LayerNormalization, BatchNormalization, Flatten, Dense, Reshape, Dropout

from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import BinaryCrossentropy
from tensorflow.keras.activations import softmax
from tensorflow.keras.utils import to_categorical


#bibliotecas para plotar graficos do keras
import pydot as pyd
import pydotplus
from pydotplus import graphviz
from tensorflow.keras.utils import plot_model, model_to_dot
tensorflow.keras.utils.pydot = pyd
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2023-07-01 18:56:39.676243: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. Importações de dados

# %%
col_names = ['gender', 'age', 'hypertension', 'heart_disease',
                'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level',
                'diabetes']

#importacao de dados
data = pd.read_csv('/home/carlos/Área de Trabalho/Faculdade/Tópicos Especiais em Engenharia de Computação/Trabalho Final/dataset/diabetes_prediction_dataset.csv', header=None, names=col_names)

# Remover a primeira linha do dataset
data = data.iloc[1:]

# Verificar se o dataset apresenta valores ausentes
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64
# /tmp/ipykernel_3715/3991910836.py:6: DtypeWarning: Columns (1,2,3,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/home/carlos/Área de Trabalho/Faculdade/Tópicos Especiais em Engenharia de Computação/Trabalho Final/dataset/diabetes_prediction_dataset.csv', header=None, names=col_names)

# %%
# Obtendo os tipos de classificações para os dados "smoking history"
smoking_classifications = data['smoking_history'].unique()
class_smoking = len(smoking_classifications)

print(smoking_classifications)
print(class_smoking)
# Out:
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']
# 6

# %%
# Obtendo os tipos de classificações para os dados "gender"
gender_classifications = data['gender'].unique()
class_gender = len(gender_classifications)

print(gender_classifications)
print(class_gender)
# Out:
# ['Female' 'Male' 'Other']
# 3

# %%
data['gender'].value_counts()
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
data['smoking_history'].value_counts()
# Out:
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking_history, dtype: int64

# %%
# Eliminação de duplicatas

data.drop_duplicates(inplace=True)

print(data)
# Out:
#         gender   age hypertension heart_disease smoking_history    bmi  \
# 1       Female  80.0            0             1           never  25.19
# 2       Female  54.0            0             0         No Info  27.32
# 3         Male  28.0            0             0           never  27.32
# 4       Female  36.0            0             0         current  23.45
# 5         Male  76.0            1             1         current  20.14
# ...        ...   ...          ...           ...             ...    ...
# 99995   Female  36.0            0             0         No Info   24.6
# 99997   Female   2.0            0             0         No Info  17.37
# 99998     Male  66.0            0             0          former  27.83
# 99999   Female  24.0            0             0           never  35.42
# 100000  Female  57.0            0             0         current  22.43
#
#        HbA1c_level blood_glucose_level diabetes
# 1              6.6                 140        0
# 2              6.6                  80        0
# 3              5.7                 158        0
# 4              5.0                 155        0
# 5              4.8                 155        0
# ...            ...                 ...      ...
# 99995          4.8                 145        0
# 99997          6.5                 100        0
# 99998          5.7                 155        0
# 99999          4.0                 100        0
# 100000         6.6                  90        0
#
# [97675 rows x 9 columns]

# %%
cat_cols = ["gender", "smoking_history"]
enc = OrdinalEncoder()

data[cat_cols] = enc.fit_transform(data[cat_cols])

print(data)
# Out:
#         gender   age hypertension heart_disease  smoking_history    bmi  \
# 1          0.0  80.0            0             1              4.0  25.19
# 2          0.0  54.0            0             0              0.0  27.32
# 3          1.0  28.0            0             0              4.0  27.32
# 4          0.0  36.0            0             0              1.0  23.45
# 5          1.0  76.0            1             1              1.0  20.14
# ...        ...   ...          ...           ...              ...    ...
# 99995      0.0  36.0            0             0              0.0   24.6
# 99997      0.0   2.0            0             0              0.0  17.37
# 99998      1.0  66.0            0             0              3.0  27.83
# 99999      0.0  24.0            0             0              4.0  35.42
# 100000     0.0  57.0            0             0              1.0  22.43
#
#        HbA1c_level blood_glucose_level diabetes
# 1              6.6                 140        0
# 2              6.6                  80        0
# 3              5.7                 158        0
# 4              5.0                 155        0
# 5              4.8                 155        0
# ...            ...                 ...      ...
# 99995          4.8                 145        0
# 99997          6.5                 100        0
# 99998          5.7                 155        0
# 99999          4.0                 100        0
# 100000         6.6                  90        0
#
# [97675 rows x 9 columns]

# %%
#converte os dados para numérico
data = data.astype(float)

#nomeia as entradas
x_names = data.columns[:-1].tolist()
y_names = data.columns[-1:].tolist()

#data = data.sample(n=20000, random_state=42)

# %%
data
# Out:
#         gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 1          0.0  80.0           0.0            1.0              4.0  25.19
# 2          0.0  54.0           0.0            0.0              0.0  27.32
# 3          1.0  28.0           0.0            0.0              4.0  27.32
# 4          0.0  36.0           0.0            0.0              1.0  23.45
# 5          1.0  76.0           1.0            1.0              1.0  20.14
# ...        ...   ...           ...            ...              ...    ...
# 99995      0.0  36.0           0.0            0.0              0.0  24.60
# 99997      0.0   2.0           0.0            0.0              0.0  17.37
# 99998      1.0  66.0           0.0            0.0              3.0  27.83
# 99999      0.0  24.0           0.0            0.0              4.0  35.42
# 100000     0.0  57.0           0.0            0.0              1.0  22.43
#
#         HbA1c_level  blood_glucose_level  diabetes
# 1               6.6                140.0       0.0
# 2               6.6                 80.0       0.0
# 3               5.7                158.0       0.0
# 4               5.0                155.0       0.0
# 5               4.8                155.0       0.0
# ...             ...                  ...       ...
# 99995           4.8                145.0       0.0
# 99997           6.5                100.0       0.0
# 99998           5.7                155.0       0.0
# 99999           4.0                100.0       0.0
# 100000          6.6                 90.0       0.0
#
# [97675 rows x 9 columns]

# %% [markdown]
# ## 3. Configurações do experimento

# %%
#realizar deteccao e substituicao de outliers
outliers_exec = True

#realizar normalizacao de dados
normalization_exec = True

#realizar escalonamento de dados
scale_exec = True

#exportar os datasets tratados
export_frames = True

#gerar um novo modelo ou usar um pronto
new_model = True

# %% [markdown]
# ## 4. Análise de dados

# %%
#conta os diagnosticos
diagnosis_counts = data['diabetes'].value_counts()

#plota o grafico
plt.figure(figsize=(6, 6))
diagnosis_counts.plot(kind='bar')
plt.xlabel('Diagnóstico')
plt.ylabel('Contagem')
plt.title('Contagem de Tipos de Diagnóstico')

#adiciona os rotulos
for i, count in enumerate(diagnosis_counts):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### 4.1 Sumarização estatística

# %%
def sumarizacao(data):
    stats = []

    for column in ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']:
        values = data[column]

        maximum = round(values.max(), 2)
        minimum = round(values.min(), 2)
        mean = round(values.mean(), 2)
        median = round(values.median(), 2)
        std = round(values.std(), 2)
        stats.append([column, maximum, minimum, mean, median, std])

    headers = ['Coluna', 'Máximo', 'Mínimo', 'Média', 'Mediana', 'Desvio Padrão']

    table = tabulate(stats, headers, tablefmt="pipe")
    print(table)

# %%
sumarizacao(data)
# Out:
# | Coluna              |   Máximo |   Mínimo |   Média |   Mediana |   Desvio Padrão |
# |:--------------------|---------:|---------:|--------:|----------:|----------------:|
# | age                 |    80    |     0.08 |   41.81 |     43    |           22.47 |
# | bmi                 |    95.69 |    10.01 |   27.32 |     27.32 |            6.71 |
# | HbA1c_level         |     9    |     3.5  |    5.53 |      5.8  |            1.07 |
# | blood_glucose_level |   300    |    80    |  138.17 |    140    |           40.83 |

# %%
fig, axs = plt.subplots(3, 3, figsize=(9, 9), tight_layout=True)

for i, atributo in enumerate(x_names):
    row = i // 3  # Linha atual
    col = i % 3   # Coluna atual
    axs[row, col].hist(data[atributo], bins=10)
    axs[row, col].set_title(atributo)
    axs[row, col].set_xlabel('Valores')
    axs[row, col].set_ylabel('Frequência')

plt.show()

# %%
columns_to_plot = ['age','gender','age','bmi', 'hypertension', 'HbA1c_level', 'blood_glucose_level', 'heart_disease']

data.boxplot(column=columns_to_plot, by='diabetes', figsize=(12, 12))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Aplicando escalonamento

# %%
#funcao que cria uma regua com valores minimos e maximos para se usar no escalonamento
def create_support_col(minvalue, maxvalue, sizecol):
    minvalues = [minvalue] * round(sizecol/2)
    maxvalues = [maxvalue] * (sizecol - round(sizecol/2))
    return [*minvalues, *maxvalues]

def minMaxIndividual(df, col, minvalue, maxvalue, rgint):
    serie = df[col].copy()

    #cria uma regua com um valor minimo e um maximo previamente determinado
    serie['support'] = create_support_col(minvalue, maxvalue, len(serie))

    #escalona considerando o minimo e o maximo especificado
    tmp = serie.to_numpy().reshape(-1,1)

    minmaxscaler = preprocessing.MinMaxScaler(feature_range=rgint).fit(tmp)
    scaled = minmaxscaler.transform(tmp).reshape(serie.shape[0], serie.shape[1])

    #remove a coluna de suporte e atualiza as colunas ja escalonadas no dataset
    df[col] = scaled[:,0:(scaled.shape[1]-1)]

    return df

# %%
data
# Out:
#         gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 1          0.0  80.0           0.0            1.0              4.0  25.19
# 2          0.0  54.0           0.0            0.0              0.0  27.32
# 3          1.0  28.0           0.0            0.0              4.0  27.32
# 4          0.0  36.0           0.0            0.0              1.0  23.45
# 5          1.0  76.0           1.0            1.0              1.0  20.14
# ...        ...   ...           ...            ...              ...    ...
# 99995      0.0  36.0           0.0            0.0              0.0  24.60
# 99997      0.0   2.0           0.0            0.0              0.0  17.37
# 99998      1.0  66.0           0.0            0.0              3.0  27.83
# 99999      0.0  24.0           0.0            0.0              4.0  35.42
# 100000     0.0  57.0           0.0            0.0              1.0  22.43
#
#         HbA1c_level  blood_glucose_level  diabetes
# 1               6.6                140.0       0.0
# 2               6.6                 80.0       0.0
# 3               5.7                158.0       0.0
# 4               5.0                155.0       0.0
# 5               4.8                155.0       0.0
# ...             ...                  ...       ...
# 99995           4.8                145.0       0.0
# 99997           6.5                100.0       0.0
# 99998           5.7                155.0       0.0
# 99999           4.0                100.0       0.0
# 100000          6.6                 90.0       0.0
#
# [97675 rows x 9 columns]

# %%
rangeinterval = (0, 1)

for col in x_names:
    data = minMaxIndividual(data, [col], np.min(data[col]), np.max(data[col]), rangeinterval)

# %%
data
# Out:
#         gender       age  hypertension  heart_disease  smoking_history  \
# 1          0.0  1.000000           0.0            1.0              0.8
# 2          0.0  0.674675           0.0            0.0              0.0
# 3          0.5  0.349349           0.0            0.0              0.8
# 4          0.0  0.449449           0.0            0.0              0.2
# 5          0.5  0.949950           1.0            1.0              0.2
# ...        ...       ...           ...            ...              ...
# 99995      0.0  0.449449           0.0            0.0              0.0
# 99997      0.0  0.024024           0.0            0.0              0.0
# 99998      0.5  0.824825           0.0            0.0              0.6
# 99999      0.0  0.299299           0.0            0.0              0.8
# 100000     0.0  0.712212           0.0            0.0              0.2
#
#              bmi  HbA1c_level  blood_glucose_level  diabetes
# 1       0.177171     0.563636             0.272727       0.0
# 2       0.202031     0.563636             0.000000       0.0
# 3       0.202031     0.400000             0.354545       0.0
# 4       0.156863     0.272727             0.340909       0.0
# 5       0.118231     0.236364             0.340909       0.0
# ...          ...          ...                  ...       ...
# 99995   0.170285     0.236364             0.295455       0.0
# 99997   0.085901     0.545455             0.090909       0.0
# 99998   0.207983     0.400000             0.340909       0.0
# 99999   0.296569     0.090909             0.090909       0.0
# 100000  0.144958     0.563636             0.045455       0.0
#
# [97675 rows x 9 columns]

# %%
sumarizacao(data)
# Out:
# | Coluna              |   Máximo |   Mínimo |   Média |   Mediana |   Desvio Padrão |
# |:--------------------|---------:|---------:|--------:|----------:|----------------:|
# | age                 |        1 |        0 |    0.52 |      0.54 |            0.28 |
# | bmi                 |        1 |        0 |    0.2  |      0.2  |            0.08 |
# | HbA1c_level         |        1 |        0 |    0.37 |      0.42 |            0.19 |
# | blood_glucose_level |        1 |        0 |    0.26 |      0.27 |            0.19 |

# %%
fig, axs = plt.subplots(3, 3, figsize=(9, 9), tight_layout=True)

for i, atributo in enumerate(x_names):
    row = i // 3  # Linha atual
    col = i % 3   # Coluna atual
    axs[row, col].hist(data[atributo], bins=10)
    axs[row, col].set_title(atributo)
    axs[row, col].set_xlabel('Valores')
    axs[row, col].set_ylabel('Frequência')

plt.show()

# %% [markdown]
# ### 4.6 Exportando ou carregando um dataset tratado

# %%
if export_frames == True:
    bar = progressbar.ProgressBar(maxval=len(data), widgets=[progressbar.Bar("=", "[", "]"), " ", progressbar.Percentage()])
    bar.start()

    x_frames = []
    y_frames = []
    
    data = data.reset_index(drop=True)  # Redefinir o índice do DataFrame
    
    cont = 0
    for ind in range(0, len(data), 1):
        x_frames.append(data.loc[ind, x_names].values)
        y_frames.append(data.loc[ind, y_names].values)
        
        bar.update(cont + 1)
        cont += 1
        
    x_frames = np.array(x_frames)
    y_frames = np.array(y_frames)
    
    dump(x_frames, 'dataset/x_frames.joblib')
    dump(y_frames, 'dataset/y_frames.joblib')

    bar.finish()
else:
    x_frames = load('dataset/x_frames.joblib')
    y_frames = load('dataset/y_frames.joblib')

print(x_frames.shape)
print(y_frames.shape)
# Out:
# [========================================================================] 100%
# (97675, 8)
# (97675, 1)

# %% [markdown]
# ## 5. Separacao dos conjuntos de dados (treino, validação e teste)

# %%
x_train_val, x_test, y_train_val, y_test = train_test_split(x_frames, y_frames, test_size=0.3, shuffle=True)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.3, shuffle=True)

print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (47860, 8)
# (47860, 1)
# (20512, 8)
# (20512, 1)
# (29303, 8)
# (29303, 1)

# %% [markdown]
# ## 6. Treinamento do modelo

# %% [markdown]
# ### 6.1 Construção do modelo

# %%
#Empilhamento de camadas para construir uma Deep Neural Network

act_function = 'tanh'
drop = 0.1
initializer = tensorflow.keras.initializers.LecunNormal()

inputs = Input(shape = (x_train.shape[1]), dtype='float32')

layer1 = Dense(16, activation=act_function, kernel_initializer=initializer)(inputs)
layer1 = Dropout(drop)(layer1)

layer2 = Dense(32, activation=act_function, kernel_initializer=initializer)(layer1)
layer2 = Dropout(drop)(layer2)

layer3 = Dense(16, activation=act_function, kernel_initializer=initializer)(layer2)
layer3 = Dropout(drop)(layer3)

outputs = Dense(y_train.shape[1], activation='sigmoid', kernel_initializer=initializer)(layer3)

#geracao do modelo
dnn_diabetes_prediction = Model(inputs, outputs)
# Out:
# /home/carlos/anaconda3/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer LecunNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %% [markdown]
# ### 6.2 Inspecionando o modelo

# %%
dnn_diabetes_prediction.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  dense (Dense)               (None, 16)                144
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 32)                544
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,233
# Trainable params: 1,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(dnn_diabetes_prediction, show_shapes=True, show_layer_names=True, rankdir="LR")  #TB para plotar na vertical

# %% [markdown]
# ### 6.3 Otimização do modelo

# %%
if (new_model == True):
    
    tensorflow.keras.backend.set_epsilon(1)
    opt = Adam(learning_rate=0.0001)
    
    dnn_diabetes_prediction.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    
    cp = ModelCheckpoint(
    filepath='models/',
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True)
    
    es = EarlyStopping(monitor='loss', mode='min', patience=25)

    history = dnn_diabetes_prediction.fit(x_train, y_train, 
                                validation_data=(x_val, y_val), 
                                epochs=150, 
                                verbose=1, 
                                callbacks=[es, cp], 
                                batch_size=8, 
                                shuffle=False)
    
    np.save('models/history_model.npy', history.history)
    dnn_diabetes_prediction.load_weights('models/')
    dnn_diabetes_prediction.save('models/dnn_diabetes_prediction.h5')
else:
    dnn_diabetes_prediction = load_model('models/dnn_diabetes_prediction.h5')
# Out:
# Epoch 1/150
# 5983/5983 [==============================] - 43s 7ms/step - loss: 0.3058 - accuracy: 0.9093 - val_loss: 0.2289 - val_accuracy: 0.9136
# Epoch 2/150
# 5983/5983 [==============================] - 34s 6ms/step - loss: 0.2006 - accuracy: 0.9245 - val_loss: 0.1470 - val_accuracy: 0.9490
# Epoch 3/150
# 5983/5983 [==============================] - 35s 6ms/step - loss: 0.
# Epoch 142/150
# 5983/5983 [==============================] - 48s 8ms/step - loss: 0.0994 - accuracy: 0.9674 - val_loss: 0.0865 - val_accuracy: 0.9720
# Epoch 143/150
# 5983/5983 [==============================] - 39s 7ms/step - loss: 0.0989 - accuracy: 0.9671 - val_loss: 0.0865 - val_accuracy: 0.9720
# Epoch 144/150
# 5983/5983 [==============================] - 40s 7ms/step - loss: 0.0989 - accuracy: 0.9674 - val_loss: 0.0865 - val_accuracy: 0.9720
# Epoch 145/150
# 5983/5983 [==============================] - 41s 7ms/step - loss: 0.0990 - accuracy: 0.9671 - val_loss: 0.0866 - val_accuracy: 0.9720
# Epoch 146/150
# 5983/5983 [==============================] - 39s 7ms/step - loss: 0.0990 - accuracy: 0.9678 - val_loss: 0.0865 - val_accuracy: 0.9721
# Epoch 147/150
# 5983/5983 [==============================] - 37s 6ms/step - loss: 0.0988 - accuracy: 0.9669 - val_loss: 0.0862 - val_accuracy: 0.9720
# Epoch 148/150
# 5983/5983 [==============================] - 43s 7ms/step - loss: 0.0981 - accuracy: 0.9674 - val_loss: 0.0864 - val_accuracy: 0.9720
# Epoch 149/150
# 5983/5983 [==============================] - 44s 7ms/step - loss: 0.0994 - accuracy: 0.9677 - val_loss: 0.0862 - val_accuracy: 0.9721
# Epoch 150/150
# 5983/5983 [==============================] - 37s 6ms/step - loss: 0.0982 - accuracy: 0.9677 - val_loss: 0.0867 - val_accuracy: 0.9719

# %% [markdown]
# ### 6.4 Avaliação do modelo com curva de convergência

# %%
history=np.load('models/history_model.npy', allow_pickle='TRUE').item()

sns.set(rc={'figure.figsize':(12, 6)})
sns.set_style('whitegrid')
sns.set_context('paper')

train_metric = history['loss']
valid_metric = history['val_loss']
name_metric = 'mse'

fig = plt.figure()

plt.plot(train_metric, label='train'), 
plt.plot(valid_metric, label='validation')
plt.ylabel(name_metric)
plt.xlabel('epoch')
plt.title('train vs. validation accuracy using ' + name_metric)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)

plt.show()

# %% [markdown]
# ## 7. Testando as previsões

# %% [markdown]
# ### 7.1 Gerando as previsões com o modelo treinado

# %%
y_hat = dnn_diabetes_prediction.predict(x_test)
y_hat, y_test = (y_hat > 0.5, y_test > 0.5)
# Out:
# 916/916 [==============================] - 3s 4ms/step

# %%
#calculando a matriz de confusao
cm = confusion_matrix(y_test.tolist(), y_hat.tolist())

#calculando a taxa de acerto
accuracy = (cm[0, 0] + cm[1, 1]) / cm.sum()
accuracy_percent = round(accuracy * 100, 2)
print("Taxa de Acerto: {:.2f}%".format(accuracy_percent))
# Out:
# Taxa de Acerto: 97.15%

# %%
plt.grid(False)
plt.imshow(cm, cmap='Blues')

plt.xlabel('Predito', fontsize=12)
plt.ylabel('Real', fontsize=12)

threshold = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        color = 'white' if cm[i, j] > threshold else 'black'
        plt.text(j, i, str(cm[i, j]), ha='center', va='center', color=color, fontsize=12)

plt.colorbar()
plt.show()

# %%
#toca um som para avisar que terminou de executar
pygame.mixer.init()
arquivo_mp3 = 'support_files/mario_coin.mp3'
pygame.mixer.music.load(arquivo_mp3)
pygame.mixer.music.play()

while pygame.mixer.music.get_busy():
    continue
    
print('Sucess!')
# Out:
# Sucess!
